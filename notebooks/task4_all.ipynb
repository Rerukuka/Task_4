# %% [markdown]
# # Task 4 — End-to-end (Synthetic dataset included)
# Run the pipeline below.

# %%
# %pip -q install -r ../requirements.txt

# %%
# %run ../scripts/train_supervised.py
# %run ../scripts/unsupervised_kmeans.py
# %run ../scripts/analyze_and_report.py
